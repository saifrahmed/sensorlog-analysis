# %%
import pandas as pd
# %matplotlib inline
import random
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv ('data/sensorlog_20190522_am1.csv')
print (df.columns)
# Out:
# Index(['loggingTime(txt)', 'loggingSample(N)', 'identifierForVendor(txt)',
#        'deviceID(txt)', 'locationTimestamp_since1970(s)',
#        'locationLatitude(WGS84)', 'locationLongitude(WGS84)',
#        'locationAltitude(m)', 'locationSpeed(m/s)', 'locationCourse(°)',
#        'locationVerticalAccuracy(m)', 'locationHorizontalAccuracy(m)',
#        'locationFloor(Z)', 'locationHeadingTimestamp_since1970(s)',
#        'locationHeadingX(µT)', 'locationHeadingY(µT)', 'locationHeadingZ(µT)',
#        'locationTrueHeading(°)', 'locationMagneticHeading(°)',
#        'locationHeadingAccuracy(°)', 'accelerometerTimestamp_sinceReboot(s)',
#        'accelerometerAccelerationX(G)', 'accelerometerAccelerationY(G)',
#        'accelerometerAccelerationZ(G)', 'gyroTimestamp_sinceReboot(s)',
#        'gyroRotationX(rad/s)', 'gyroRotationY(rad/s)', 'gyroRotationZ(rad/s)',
#        'magnetometerTimestamp_sinceReboot(s)', 'magnetometerX(µT)',
#        'magnetometerY(µT)', 'magnetometerZ(µT)',
# ...

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
df.head()
# Out:
#                 loggingTime(txt)  loggingSample(N)              identifierForVendor(txt)  deviceID(txt)  locationTimestamp_since1970(s)  locationLatitude(WGS84)  locationLongitude(WGS84)  locationAltitude(m)  locationSpeed(m/s)  locationCourse(°)  locationVerticalAccuracy(m)  locationHorizontalAccuracy(m)  locationFloor(Z)  locationHeadingTimestamp_since1970(s)  locationHeadingX(µT)  locationHeadingY(µT)  locationHeadingZ(µT)  locationTrueHeading(°)  locationMagneticHeading(°)  locationHeadingAccuracy(°)  accelerometerTimestamp_sinceReboot(s)  accelerometerAccelerationX(G)  accelerometerAccelerationY(G)  accelerometerAccelerationZ(G)  gyroTimestamp_sinceReboot(s)  gyroRotationX(rad/s)  gyroRotationY(rad/s)  gyroRotationZ(rad/s)  magnetometerTimestamp_sinceReboot(s)  magnetometerX(µT)  magnetometerY(µT)  magnetometerZ(µT)  motionTimestamp_sinceReboot(s)  motionYaw(rad)  motionRoll(rad)  motionPitch(rad)  motionRotationRateX(rad/s)  motionRotationRateY(rad/s)  \
# ...

# %%
# simple stats
colname = 'accelerometerAccelerationZ(G)'
mean1 = df[colname].mean()
sum1 = df[colname].sum()
max1 = df[colname].max()
min1 = df[colname].min()
count1 = df[colname].count()
median1 = df[colname].median() 
std1 = df[colname].std() 
var1 = df[colname].var()

# %%
sns.kdeplot(df['accelerometerAccelerationY(G)'])
